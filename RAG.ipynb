# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanushiya-srini/GenAI-apex/blob/main/RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 27.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 25.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.25
#     Uninstalling langchain-core-0.3.25:
#       Successfully uninstalled langchain-core-0.3.25
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.12
#     Uninstalling langchain-0.3.12:
#       Successfully uninstalled langchain-0.3.12
# ...

# %%
from langchain.document_loaders import PyPDFLoader

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 4.9 MB/s eta 0:00:00
# ...

# %%
loader= PyPDFLoader("/Anna University Profile.pdf")

# %%
document=loader.load()

# %%
document
# Out:
# [Document(metadata={'source': '/Anna University Profile.pdf', 'page': 0}, page_content=" \n \nANNA UNIVERSITY \nCHENNAI 25 \n \n \n \n \n \nBRIEF HISTORY OF ANNA UNIVERSITY: \n \n \n \n \nAnna University was established on 4th  September, 1978 as a unitary type of \nUniversity.  This University was named after Late Dr.C.N.Annadurai, former Chief Minister \nof Tamil Nadu.   It offers higher education in Engineering, Technology, Architecture and \nApplied Sciences rel evant to  the current and projected needs of the society. B esides \npromoting research and disseminating knowledge gained therefrom, it fosters cooperation \nbetween the academic and industrial communities. \n \n \nThe University was formed by bringing together and integrating four well known \ntechnical institutions in the city of Madras (now Chennai) namely, \n \n \nCollege of Engineering                            (CEG) (Established in 1794) \nAlagappa College of Technology            (ACT) (Established in 1944) \nMad
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter=RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=10,length_function=len,keep_separator=False)

# %%
docu=text_splitter.split_documents(document)

# %%
docu[200]
# Out:
# Document(metadata={'source': '/Anna University Profile.pdf', 'page': 5}, page_content='Engineering for t he payment of Tuition Fees etc. through the web portal')

# %%
# !pip install sentence-transformers

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
embeddings=HuggingFaceEmbeddings()
# Out:
# <ipython-input-30-5897ca6a0cdb>:1: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embeddings=HuggingFaceEmbeddings()

# %%
embeddings.embed_query("Hi young engineers how is genai")
# Out:
# [-0.013013102114200592,
#  -0.021287094801664352,
#  -0.03161142021417618,
#  0.05543346703052521,
#  -0.0013796091079711914,
#  -0.009432967752218246,
#  -0.013644388876855373,
#  0.009893769398331642,
#  -0.010176400654017925,
#  0.011202981695532799,
#  0.008691449649631977,
#  -0.03726595640182495,
#  0.016945872455835342,
#  0.07020068913698196,
#  -0.008255834691226482,
#  -0.003993720281869173,
#  0.028922535479068756,
#  -0.011681417003273964,
#  -0.017153248190879822,
#  -0.03038278967142105,
#  -0.01810801401734352,
#  -0.03347310423851013,
#  -0.03369949385523796,
#  0.04441181570291519,
#  -0.00802940409630537,
#  0.003266773419454694,
#  0.03290252014994621,
#  -0.004468364641070366,
#  0.012241097167134285,
#  -0.0011403757380321622,
#  -0.01701941341161728,
#  0.030861422419548035,
#  -0.04435570165514946,
#  0.06694858521223068,
#  1.461704073335568e-06,
#  0.00404787203297019,
#  0.05302815139293671,
#  0.04001475125551224,
#  0.0053901681676507,
# ...

# %%
pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 39.4 MB/s eta 0:00:00
# ...

# %%
from langchain.vectorstores import FAISS

# %%
result=FAISS.from_documents(docu,embeddings)

# %%
type(result)
# Out:
# langchain_community.vectorstores.faiss.FAISS

# %%
result.similarity_search(" how many Constituent Colleges Anna University have")
# Out:
# [Document(id='8b03c6b3-76ae-4bf2-9414-b7fbdaabce67', metadata={'source': '/Anna University Profile.pdf', 'page': 0}, page_content='Campuses),  presently,  Anna  University  has  13  Constituent  Colle ges,  3  Regional'),
#  Document(id='9ec5a6ed-66d0-42b0-8a87-65257caf41fd', metadata={'source': '/Anna University Profile.pdf', 'page': 2}, page_content='Anna University offers 29 UG and 90 PG Programmes in various disciplines in \nthe'),
#  Document(id='08ad2396-c26e-4d39-a3b9-8a2c2b40d9c5', metadata={'source': '/Anna University Profile.pdf', 'page': 0}, page_content='Anna University was established on 4th  September, 1978 as a unitary type of'),
#  Document(id='73327bb3-1e7a-44a3-8309-f5ae52c652ab', metadata={'source': '/Anna University Profile.pdf', 'page': 5}, page_content='students  of  Anna  University  have  studied  in  Anna  University  and  foreign')]
