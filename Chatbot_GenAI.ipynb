# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanushiya-srini/GenAI-apex/blob/main/Chatbot_GenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyBhdZexodlMcf942Flwgkl1vTx0pq3_DWE")

# %%
import google.generativeai as genai

# %%
for i in genai.list_models():
  print(i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# ...

# %%
model=genai.GenerativeModel("gemini-pro")

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
model.generate_content("what is science").text
# Out:
# '**Science** is a systematic and organized body of knowledge about the natural world. It is based on empirical evidence and is constantly evolving as new discoveries are made.\n\n**Key Characteristics of Science:**\n\n* **Objectivity:** Science seeks to provide unbiased and dispassionate observations and explanations of the natural world. It relies on data and evidence rather than subjective opinions or beliefs.\n* **Empiricism:** Science is based on repeatable observations and experiments. Researchers collect data, test hypotheses, and develop theories that can be supported by evidence.\n* **Hypothesis Testing:** Scientists propose hypotheses (testable statements) and design experiments to either support or refute them. This iterative process helps eliminate false ideas and refine existing theories.\n* **Peer Review:** Scientific findings are subject to rigorous peer review by other scientists. This process ensures the validity, accuracy, and objectivity of the research.\n* **Replic
# ...

# %%
a=genai.GenerativeModel("gemini-1.0-pro")

# %%
a.generate_content("what is world").text
# Out:
# 'The world, in a broad sense, refers to the totality of everything that exists or is known, including all matter, energy, space, and time. In other words, it encompasses the entire universe and everything within it.\n\nFrom a physical perspective, the world can be described as a vast cosmos governed by fundamental laws of physics. It consists of galaxies, stars, planets, moons, and various forms of matter and energy. The world is constantly evolving and expanding, with new discoveries and advancements in our understanding of it being made all the time.\n\nBeyond the physical realm, the world also includes the realm of human experience and consciousness. It encompasses human societies, cultures, histories, beliefs, and values. The world of human experience is influenced by our interactions with the physical environment, social and cultural factors, and our subjective perceptions and interpretations.\n\nIn a metaphorical sense, the world can also refer to a particular region, country, 
# ...

# %%
vision_model=genai.GenerativeModel("gemini-pro-vision")

# %%
vision_model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro-vision',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
from PIL import Image

# %% [markdown]
# img=Image.open("/content/imga.jpeg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=263x180>

# %%
vision_model1=genai.GenerativeModel("gemini-1.5-flash")

# %%
vision_model1.generate_content(["what is in this image",Image.open("/content/imga.jpeg")]).text
# Out:
# "That's a picture of a tropical beach scene.  More specifically:\n\n* **A sandy beach:**  White sand stretches along the shoreline.\n* **Clear turquoise water:** The ocean is a vibrant blue-green, suggesting shallow, clear water.\n* **Karst limestone cliffs:**  Dramatic, reddish-brown cliffs rise up from behind the beach, characteristic of areas like Thailand or parts of Southeast Asia.  These cliffs are covered in lush green vegetation.\n* **A longtail boat:** A traditional Thai longtail boat is anchored in the calm water near the shore.\n* **Blue sky with clouds:** The sky is a bright, clear blue with fluffy white clouds.\n\n\nThe overall impression is one of a picturesque, idyllic tropical paradise.  The style of the image suggests it might be slightly enhanced or idealized, common in travel photography.\n"

# %%
model_text=genai.GenerativeModel("gemini-1.5-flash")

# %%
print(model_text.generate_content(["what are colors in the image",img]).text)
# Out:
# That's a lovely beach scene!  The prominent colors in the image are:
#
# * **Bright Blue:** This is the dominant color, representing the clear sky and the turquoise water.  There are variations in the shade of blue, from a deeper blue in the sky to a lighter, more teal blue in the ocean.
#
# * **White/Off-White:** The beach sand is a bright, almost pure white in some areas, grading into a slightly off-white or beige closer to the water's edge.
#
# * **Browns/Oranges/Reds:** The cliffs and rocks are various shades of brown, orange, and red, suggesting weathered rock formations.
#
# * **Greens:** Lush green vegetation covers the lower slopes of the cliffs and hills.  The shades range from light to dark greens.
#
#
# The overall color palette is vibrant and tropical, giving a feeling of warmth and serenity.
